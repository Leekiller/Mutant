# %% [markdown]
# # Backtesting Mutant v23.08
#
# ## Backtest Method
#     30 days as a group, randomly choose 30 continuos 30 days to see the performance

# %%
# from __future__ import (absolute_import, division, print_function,
#                         unicode_literals)
import datetime
# import os.path
import sys

import pandas as pd
import numpy as np
import backtrader as bt
import backtrader.indicators as ta

import matplotlib
import tkinter
matplotlib.use('TKAgg')
# matplotlib.use('QT5Agg')

from mutant.model import Mutant
from mutant.strategy import MutantBacktrader

raw_data_path = "../data/BTCUSD_latest.csv"
# raw_data_path = "../data/Raw_BTCUSDT1708-2303.csv"

# %% [markdown]
# ## Load data

# %%
dataframe = pd.read_csv(raw_data_path,
                                parse_dates=True,
                                index_col=0)
dataframe.index = pd.to_datetime(dataframe.index, format='ISO8601')

# %%
model = Mutant()
trade_reports = []
drawdown_reports = []
total_sessions = 1
for i in range(total_sessions):
    backtest_length = 1440*30
    start = np.random.choice(len(dataframe))
    end = start + backtest_length
    df = dataframe.iloc[start:end]
    df = df.groupby(pd.Grouper(freq='5Min')).agg({"open": "first", 
                                                  "high": "max",
                                                  "low": "min",
                                                  "close": "last",
                                                  "volume": "sum"})
    data = bt.feeds.PandasData(
        dataname=df,
        # fromdate=datetime.datetime(2022, 9, 1),
        # todate=datetime.datetime(2022, 9, 2),
        datetime=None,)
    cerebro = bt.Cerebro()
    cerebro.addstrategy(MutantBacktrader, model)
    cerebro.adddata(data)
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='mutant_trade')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='mutant_drawdown')
    cerebro.addsizer(bt.sizers.PercentSizer, percents=10)
    cerebro.broker.setcash(100000.0)
    cerebro.broker.setcommission(commission=0.0004)
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    result = results[0]
    trade_reports.append(result.analyzers.mutant_trade.get_analysis())
    drawdown_reports.append(result.analyzers.mutant_drawdown.get_analysis())
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2018-07-16T03:20:00, BUY CREATE, 6361.02
# 2018-07-16T03:25:00, BUY EXECUTED, Price: 6361.02, Cost: 10000.00, Comm 4.00
# 2018-07-16T08:50:00, SELL EXECUTED, Price: 6402.17, Cost: 10000.00, Comm 4.03
# 2018-07-16T08:50:00, Order Canceled/Margin/Rejected
# 2018-07-16T08:50:00, OPERATION PROFIT, GROSS 64.70, NET 56.67
# 2018-07-17T11:55:00, SELL CREATE, 6675.76
# 2018-07-17T12:00:00, SELL EXECUTED, Price: 6675.76, Cost: -10005.67, Comm 4.00
# 2018-07-17T15:55:00, BUY EXECUTED, Price: 6788.09, Cost: -10005.67, Comm 4.07
# 2018-07-17T15:55:00, Order Canceled/Margin/Rejected
# 2018-07-17T15:55:00, OPERATION PROFIT, GROSS -168.35, NET -176.43
# 2018-07-28T09:15:00, SELL EXECUTED, Price: 8177.99, Cost: -9988.48, Comm 4.00
# 2018-07-28T14:20:00, BUY EXECUTED, Price: 8127.24, Cost: -9988.48, Comm 3.97
# 2018-07-28T14:20:00, Order Canceled/Margin/Rejected
# 2018-07-28T14:20:00, OPERATION PROFIT, GROSS 61.98, NET 54.02
# 2018-07-28T16:15:00, BUY CREATE, 8174.78
# 2018-07-28T16:20:00, BUY EXECUTED, Price: 8174.80, Cost: 9993.23, Comm 4.00
# 2018-07-28T23:55:00, SELL EXECUTED, Price: 8230.76, Cost: 9993.23, Comm 4.02
# 2018-07-28T23:55:00, Order Canceled/Margin/Rejected
# 2018-07-28T23:55:00, OPERATION PROFIT, GROSS 68.41, NET 60.39
# 2018-07-29T16:10:00, SELL CREATE, 8192.23
# 2018-07-29T16:15:00, SELL EXECUTED, Price: 8192.24, Cost: -9999.26, Comm 4.00
# 2018-07-30T00:05:00, BUY EXECUTED, Price: 8141.96, Cost: -9999.26, Comm 3.98
# 2018-07-30T00:05:00, Order Canceled/Margin/Rejected
# 2018-07-30T00:05:00, OPERATION PROFIT, GROSS 61.37, NET 53.39
# 2018-07-30T01:25:00, BUY CREATE, 8201.68
# 2018-07-30T01:30:00, BUY EXECUTED, Price: 8201.69, Cost: 10004.60, Comm 4.00
# 2018-07-30T17:35:00, SELL EXECUTED, Price: 8054.06, Cost: 10004.60, Comm 3.93
# 2018-07-30T17:35:00, Order Canceled/Margin/Rejected
# 2018-07-30T17:35:00, OPERATION PROFIT, GROSS -180.08, NET -188.01
# 2018-07-30T19:35:00, BUY CREATE, 8100.01
# 2018-07-30T19:40:00, BUY EXECUTED, Price: 8100.00, Cost: 9985.77, Comm 3.99
# 2018-07-30T20:25:00, SELL EXECUTED, Price: 8163.69, Cost: 9985.77, Comm 4.03
# 2018-07-30T20:25:00, Order Canceled/Margin/Rejected
# 2018-07-30T20:25:00, OPERATION PROFIT, GROSS 78.52, NET 70.50
# 2018-07-31T05:45:00, BUY CREATE, 8126.51
# 2018-07-31T05:50:00, BUY EXECUTED, Price: 8126.52, Cost: 9992.85, Comm 4.00
# 2018-07-31T09:15:00, SELL EXECUTED, Price: 7980.44, Cost: 9992.85, Comm 3.93
# 2018-07-31T09:15:00, Order Canceled/Margin/Rejected
# 2018-07-31T09:15:00, OPERATION PROFIT, GROSS -179.63, NET -187.55
# 2018-08-01T13:05:00, BUY CREATE, 7605.99
# 2018-08-01T13:10:00, BUY EXECUTED, Price: 7606.00, Cost: 9974.09, Comm 3.99
# 2018-08-01T21:55:00, SELL EXECUTED, Price: 7469.09, Cost: 9974.09, Comm 3.92
# 2018-08-01T21:55:00, Order Canceled/Margin/Rejected
# 2018-08-01T21:55:00, OPERATION PROFIT, GROSS -179.53, NET -187.44
# 2018-08-01T22:05:00, BUY CREATE, 7577.22
# 2018-08-01T22:10:00, BUY EXECUTED, Price: 7577.21, Cost: 9955.32, Comm 3.98
# 2018-08-02T00:20:00, SELL EXECUTED, Price: 7650.69, Cost: 9955.32, Comm 4.02
# 2018-08-02T00:20:00, Order Canceled/Margin/Rejected
# 2018-08-02T00:20:00, OPERATION PROFIT, GROSS 96.54, NET 88.54
# 2018-08-04T09:30:00, SELL CREATE, 7433.58
# 2018-08-04T09:35:00, SELL EXECUTED, Price: 7433.58, Cost: -9964.19, Comm 3.99
# 2018-08-04T10:30:00, BUY EXECUTED, Price: 7383.74, Cost: -9964.19, Comm 3.96
# 2018-08-04T10:30:00, Order Canceled/Margin/Rejected
# 2018-08-04T10:30:00, OPERATION PROFIT, GROSS 66.81, NET 58.86
# 2018-08-05T15:05:00, BUY CREATE, 7010.65
# 2018-08-05T15:10:00, BUY EXECUTED, Price: 7011.98, Cost: 9971.97, Comm 3.99
# 2018-08-05T20:45:00, SELL EXECUTED, Price: 7067.15, Cost: 9971.97, Comm 4.02
# 2018-08-05T20:45:00, Order Canceled/Margin/Rejected
# 2018-08-05T20:45:00, OPERATION PROFIT, GROSS 78.46, NET 70.45
# 2018-08-05T22:10:00, SELL CREATE, 7007.99
# 2018-08-05T22:15:00, SELL EXECUTED, Price: 7008.00, Cost: -9977.14, Comm 3.99
# 2018-08-06T01:40:00, BUY EXECUTED, Price: 7128.08, Cost: -9977.14, Comm 4.06
# 2018-08-06T01:40:00, Order Canceled/Margin/Rejected
# 2018-08-06T01:40:00, OPERATION PROFIT, GROSS -170.95, NET -179.00
# 2018-08-09T10:30:00, BUY CREATE, 6325.37
# 2018-08-09T10:35:00, BUY EXECUTED, Price: 6325.37, Cost: 9959.22, Comm 3.98
# 2018-08-09T13:10:00, SELL EXECUTED, Price: 6213.86, Cost: 9959.22, Comm 3.91
# 2018-08-09T13:10:00, Order Canceled/Margin/Rejected
# 2018-08-09T13:10:00, OPERATION PROFIT, GROSS -175.57, NET -183.47
# 2018-08-09T13:45:00, BUY CREATE, 6402.73
# 2018-08-09T13:50:00, BUY EXECUTED, Price: 6402.73, Cost: 9940.87, Comm 3.98
# 2018-08-09T14:55:00, SELL EXECUTED, Price: 6513.85, Cost: 9940.87, Comm 4.05
# 2018-08-09T14:55:00, Order Canceled/Margin/Rejected
# 2018-08-09T14:55:00, OPERATION PROFIT, GROSS 172.52, NET 164.50
# 2018-08-11T13:30:00, BUY CREATE, 6125.44
# 2018-08-11T13:35:00, BUY EXECUTED, Price: 6121.66, Cost: 9951.18, Comm 3.98
# 2018-08-11T17:15:00, SELL EXECUTED, Price: 6165.64, Cost: 9951.18, Comm 4.01
# 2018-08-11T17:15:00, Order Canceled/Margin/Rejected
# 2018-08-11T17:15:00, OPERATION PROFIT, GROSS 71.50, NET 63.51
# 2018-08-12T08:10:00, SELL CREATE, 6289.16
# 2018-08-12T08:15:00, SELL EXECUTED, Price: 6289.16, Cost: -9963.68, Comm 3.99
# 2018-08-12T12:45:00, BUY EXECUTED, Price: 6245.17, Cost: -9963.68, Comm 3.96
# 2018-08-12T12:45:00, Order Canceled/Margin/Rejected
# 2018-08-12T12:45:00, OPERATION PROFIT, GROSS 69.69, NET 61.74
# 2018-08-12T16:10:00, SELL CREATE, 6263.46
# 2018-08-12T16:15:00, SELL EXECUTED, Price: 6260.28, Cost: -9964.79, Comm 3.99
# 2018-08-12T19:35:00, BUY EXECUTED, Price: 6367.59, Cost: -9964.79, Comm 4.05
# 2018-08-12T19:35:00, Order Canceled/Margin/Rejected
# 2018-08-12T19:35:00, OPERATION PROFIT, GROSS -170.81, NET -178.85
# 2018-08-12T19:40:00, SELL CREATE, 6297.56
# 2018-08-12T19:45:00, SELL EXECUTED, Price: 6286.76, Cost: -9934.90, Comm 3.97
# 2018-08-12T19:50:00, BUY EXECUTED, Price: 6322.93, Cost: -9934.90, Comm 4.00
# 2018-08-12T19:50:00, Order Canceled/Margin/Rejected
# 2018-08-12T19:50:00, OPERATION PROFIT, GROSS -57.16, NET -65.13
# 2018-08-12T23:15:00, SELL CREATE, 6310.47
# 2018-08-12T23:20:00, SELL EXECUTED, Price: 6310.46, Cost: -9945.44, Comm 3.98
# 2018-08-13T06:15:00, BUY EXECUTED, Price: 6414.05, Cost: -9945.44, Comm 4.04
# 2018-08-13T06:15:00, Order Canceled/Margin/Rejected
# 2018-08-13T06:15:00, OPERATION PROFIT, GROSS -163.26, NET -171.28
# Final Portfolio Value: 99283.24

# %%
""" Trade report is provided by Backtrader.analyzers.TradeAnalyzer

"""
def get_win_rate(trade_raport):
    """ Get the win rate from trade report
    
    Win rate = number of win trades / number of total trades
    """
    total_trades = trade_raport['total']['total']
    win_trades = trade_raport['won']['total']
    win_rate = win_trades / total_trades
    return win_rate

def get_roi(trade_raport, init_protfolio_value=100000.0):
    """ Get the ROI from trade report

    ROI = PNL / Initial Portfolio Value
    """
    pnl = trade_raport['pnl']['net']['total']
    roi = pnl / init_protfolio_value
    return roi

def get_drawdown(drawdown_report):
    """ Get the drawdown from drawdown report

    """
    drawdown = drawdown_report['drawdown']
    return drawdown

# %%
sessions_win = 0
sessions_win_rate = 0
for i in range(total_sessions):
    trade_report = trade_reports[i]
    drawdown_report = drawdown_reports[i]
    win_rate = get_win_rate(trade_report)
    roi = get_roi(trade_report)
    if roi > 0:
        sessions_win += 1
    drawdown = get_drawdown(drawdown_report)
    print("total_trades: {}, win_rate: {:.2f},  roi: {:.2f}%, drawdown: {:.2f}%.".format(trade_report['total']['total'], win_rate, roi*100, drawdown))
sessions_win_rate = sessions_win/total_sessions * 100
print("sessions_win_rate: {:.2f}%.".format(sessions_win_rate))
# Out:
# total_trades: 27, win_rate: 0.59,  roi: -0.72%, drawdown: 0.80%.
# sessions_win_rate: 0.00%.
